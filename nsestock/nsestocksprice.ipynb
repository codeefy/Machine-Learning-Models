# %%
import pandas as pd
df=pd.read_csv('nse_all_stock_data.csv')
df.head()
# Out:
#          Date  RELIANCE  TCS  HDFCBANK  ICICIBANK  BHARTIARTL  SBIN  INFY  \
# 0  1991-01-02       NaN  NaN       NaN        NaN         NaN   NaN   NaN
# 1  1991-01-03       NaN  NaN       NaN        NaN         NaN   NaN   NaN
# 2  1991-01-04       NaN  NaN       NaN        NaN         NaN   NaN   NaN
# 3  1991-01-07       NaN  NaN       NaN        NaN         NaN   NaN   NaN
# 4  1991-01-08       NaN  NaN       NaN        NaN         NaN   NaN   NaN
#
#    LICI  ITC  ...  COOLCAPS  ALLETEC  20MICRONS  VIKASECO  ORIENTBELL  DONEAR  \
# 0   NaN  NaN  ...       NaN      NaN        NaN       NaN         NaN     NaN
# 1   NaN  NaN  ...       NaN      NaN        NaN       NaN         NaN     NaN
# 2   NaN  NaN  ...       NaN      NaN        NaN       NaN         NaN     NaN
# 3   NaN  NaN  ...       NaN      NaN        NaN       NaN         NaN     NaN
# 4   NaN  NaN  ...       NaN      NaN        NaN       NaN         NaN     NaN
#
#    CAREERP  INTLCONV  SHREEPUSHK  PRITIKAUTO
# 0      NaN       NaN         NaN         NaN
# 1      NaN       NaN         NaN         NaN
# 2      NaN       NaN         NaN         NaN
# 3      NaN       NaN         NaN         NaN
# 4      NaN       NaN         NaN         NaN
#
# [5 rows x 1418 columns]

# %%
l = {}

for i in df.columns:
    if i != 'Date':
        l[i]= df[i].mean() # mean of each column except Date column

# %%
# create a list of columns with null values >8000
null_cols = []
for i in df.columns:
    if df[i].isnull().sum() > 8000:
        null_cols.append(i)

print(null_cols)
# Out:
# ['JIOFIN', 'ADANIENSOL', 'MANKIND', 'JSWINFRA', 'TATATECH', 'L&TFH', 'IREDA', 'MEDANTA', 'LLOYDSME', 'FIVESTAR', 'SIGNATURE', 'JYOTICNC', 'KAYNES', 'KPIL', 'RRKABEL', 'PPLPHARMA', 'NUVAMA', 'CELLO', 'NSLNISP', 'CONCORDBIO', 'HONASA', 'PVRINOX', 'ARE&M', 'BIKAJI', 'JUNIPER', 'INOXINDIA', 'KFINTECH', 'PTCIL', 'DOMS', 'REDTAPE', 'NETWEB', 'SBFC', 'HAPPYFORGE', 'SYRMA', 'ACI', 'AZAD', 'JLHL', 'TMB', 'EMIL', 'RUSTOMJEE', 'NIITMTS', 'TVSSCS', 'INDIASHLTR', 'BLUEJET', 'LTFOODS', 'SENCO', 'SANDUMA', 'UJJIVAN', 'CYIENTDLM', 'ASKAUTOLTD', 'LLOYDSENGG', 'HNDFDS', 'UTKARSHBNK', 'FUSION', 'SULA', 'SAMHI', 'KIRLPNU', 'EPIGRAL', 'GOPAL', 'SINDHUTRAD', 'ENTERO', 'JSFB', 'FEDFINA', 'PARKHOTELS', 'MAXESTATES', 'AARTIPHARM', 'HARSHA', 'YATHARTH', 'ZAGGLE', 'MEDIASSIST', 'INOXGREEN', 'MUTHOOTMF', 'GENSOL', 'DCXINDIA', 'AVALON', 'KALAMANDIR', 'LANDMARK', 'IDEAFORGE', 'SUNCLAY', 'BLSE', 'ESAFSFB', 'FLAIR', 'DREAMFOLKS', 'INNOVACAP', 'HMAAGRO', 'BAJEL', 'SPECTRUM', 'EXICOM', 'UNIPARTS', 'DIVGIITTS', 'YATRA', 'EMSLIMITED', 'NPST', 'IKIO', 'UDS', 'JSLL', 'RPTECH', 'MUFIN', 'SIGNPOST', 'GANDHAR', 'IRMENERGY', 'VPRPL', 'SCILAL', 'YASHO', 'PVSL', 'RISHABH', 'MOTISONS', 'CAPITALSFB', 'AEROFLEX', 'SADHNANIQ', 'SBGLP', 'EPACK', 'GPTHEALTH', 'ORIANA', 'RKSWAMY', 'AHL', 'ATL', 'GIRIRAJ', 'SKYGOLD', 'MVGJL', 'BETA', 'SAURASHCEM', 'SURAJEST', 'SICALLOG', 'TREL', 'PAKKA', 'INNOVANA', 'MUKKA', 'MUFTI', 'KRYSTAL', 'SPORTKING', 'KOTYARK', 'KAMOPAINTS', 'SYNCOMF', 'REMUS', 'BLAL', 'SATINDLTD', 'GSLSU', 'PLATIND', 'AMNPLST', 'NINSYS', 'OWAIS', 'TRACXN', 'FAZE3Q', 'BASILIC', 'ALPEXSOLAR', 'RADIANTCMS', 'DENTALKART', 'DBOL', 'DHARMAJ', 'VINYAS', 'TRU', 'GHCLTEXTIL', 'DAVANGERE', 'GRMOVER', 'SUKHJITS', 'EMKAYTOOLS', 'SAHANA', 'JGCHEM', 'ANNAPURNA', 'ELIN', 'SOLEX', 'VALIANTLAB', 'PHANTOMFX', 'KODYTECH', 'RBZJEWEL', 'ORIENTCER', 'KRISHIVAL', 'RATNAVEER', 'VISHNUINFR', 'VLEGOV', 'RACE', 'PYRAMID', 'ACCENTMIC', 'COOLCAPS', 'ALLETEC']

# %%
# create a new df with columns not in null_cols
df2 = df.drop(columns=null_cols)

# fill the remaining null values with the mean of the column not with date column
df2.fillna(l, inplace=True)
df2
# Out:
#             Date     RELIANCE          TCS     HDFCBANK    ICICIBANK  \
# 0     1991-01-02   605.661551  1221.558660   437.622147   296.793689
# 1     1991-01-03   605.661551  1221.558660   437.622147   296.793689
# 2     1991-01-04   605.661551  1221.558660   437.622147   296.793689
# 3     1991-01-07   605.661551  1221.558660   437.622147   296.793689
# 4     1991-01-08   605.661551  1221.558660   437.622147   296.793689
# ...          ...          ...          ...          ...          ...
# 8465  2024-07-01  3120.300049  3978.199951  1705.199951  1211.849976
# 8466  2024-07-02  3130.350098  4017.399902  1730.599976  1190.599976
# 8467  2024-07-03  3104.850098  3965.250000  1768.650024  1201.599976
# 8468  2024-07-04  3108.050049  4020.949951  1727.150024  1233.000000
# 8469  2024-07-05  3177.250000  4011.800049  1648.099976  1233.400024
#
#        BHARTIARTL        SBIN         INFY         LICI         ITC  ...  \
# 0      359.974920  188.679499   429.695286   726.020834  133.909118  ...
# 1      359.974920  188.679499   429.695286   726.020834  133.909118  ...
# 2      359.974920  188.679499   429.695286   726.020834  133.909118  ...
# 3      359.974920  188.679499   429.695286   726.020834  133.909118  ...
# 25%      43.955097   113.641209   726.020834    22.924722   207.762501  ...
# 50%     188.679499   358.118744   726.020834   133.909118   455.875000  ...
# 75%     253.587505   496.924988   726.020834   216.283337   851.274994  ...
# max     905.650024  1939.500000  1105.250000   492.149994  2812.449951  ...
#
#              MAZDA     MINDTECK    20MICRONS     VIKASECO   ORIENTBELL  \
# count  8470.000000  8470.000000  8470.000000  8470.000000  8470.000000
# mean    563.316218    92.740286    46.816379     4.378091   173.385619
# std     146.195258    31.630378    23.512162     1.748618   113.017904
# min     233.699997    12.750000     7.100000     0.624703    14.000000
# 25%     563.316218    92.740286    36.549999     4.378091   107.949997
# 50%     563.316218    92.740286    46.816379     4.378091   173.385619
# 75%     563.316218    92.740286    46.816379     4.378091   173.385619
# max    1556.550049   340.299988   227.800003    17.518017   806.200012
#
#             DONEAR      CAREERP     INTLCONV   SHREEPUSHK   PRITIKAUTO
# count  8470.000000  8470.000000  8470.000000  8470.000000  8470.000000
# mean     49.874282   155.291620    71.400780   171.467658    20.554881
# std      32.564955    50.613490     3.841359    27.603618     2.127224
# min       8.900000    51.150002    47.750000    59.349998    12.700000
# 25%      31.400000   150.000000    71.400780   171.467658    20.554881
# 50%      49.874282   155.291620    71.400780   171.467658    20.554881
# 75%      49.874282   155.291620    71.400780   171.467658    20.554881
# max     236.149994   660.000000   119.900002   332.000000    52.000000
#
# [8 rows x 1241 columns]

# %%
#null Values
df2.isnull().sum()
# Out:
# Date          0
# RELIANCE      0
# TCS           0
# HDFCBANK      0
# ICICIBANK     0
#              ..
# DONEAR        0
# CAREERP       0
# INTLCONV      0
# SHREEPUSHK    0
# PRITIKAUTO    0
# Length: 1242, dtype: int64

# %%
# count duplicate rows
df2.duplicated().sum()
df2.drop_duplicates(inplace=True)
df2.shape
# Out:
# (8470, 1242)

# %%
# Out:
# {'RELIANCE': 0, 'TCS': 0, 'HDFCBANK': 0, 'ICICIBANK': 0, 'BHARTIARTL': 0, 'SBIN': 0, 'INFY': 0, 'LICI': 0, 'ITC': 0, 'HINDUNILVR': 0, 'LT': 0, 'BAJFINANCE': 0, 'HCLTECH': 0, 'MARUTI': 0, 'SUNPHARMA': 0, 'ADANIENT': 0, 'KOTAKBANK': 0, 'TITAN': 0, 'ONGC': 0, 'TATAMOTORS': 0, 'NTPC': 0, 'AXISBANK': 0, 'DMART': 0, 'ADANIGREEN': 0, 'ADANIPORTS': 0, 'ULTRACEMCO': 0, 'ASIANPAINT': 0, 'COALINDIA': 0, 'BAJAJFINSV': 0, 'BAJAJ-AUTO': 0, 'POWERGRID': 0, 'NESTLEIND': 0, 'WIPRO': 0, 'M&M': 0, 'IOC': 0, 'HAL': 0, 'DLF': 0, 'ADANIPOWER': 0, 'JSWSTEEL': 0, 'TATASTEEL': 0, 'SIEMENS': 0, 'IRFC': 0, 'VBL': 0, 'ZOMATO': 0, 'PIDILITIND': 0, 'GRASIM': 0, 'SBILIFE': 0, 'BEL': 0, 'LTIM': 0, 'TRENT': 0, 'PNB': 0, 'INDIGO': 0, 'BANKBARODA
AUBANK': 0, 'MAZDOCK': 0, 'HUDCO': 0, 'GUJGASLTD': 0, 'NIACL': 0, 'CRISIL': 0, 'AIAENG': 0, 'FEDERALBNK': 0, 'VOLTAS': 0, 'DALBHARAT': 0, 'POONAWALLA': 0, 'IRB': 0, '3MINDIA': 0, 'MFSL': 0, 'M&MFIN': 0, 'UPL': 0, 'HONAUT': 0, 'BSE': 0, 'FLUOROCHEM': 0, 'COFORGE': 0, 'LICHSGFIN': 0, 'GLAXO': 0, 'DELHIVERY': 0, 'BDL': 0, 'STARHEALTH': 0, 'FORTIS': 0, 'BIOCON': 0, 'COROMANDEL': 0, 'NLCINDIA': 0, 'TATAINVEST': 0, 'JKCEMENT': 0, 'IPCALAB': 0, 'METROBRAND': 0, 'KEI': 0, 'ESCORTS': 0, 'GLAND': 0, 'IGL': 0, 'NAM-INDIA': 0, 'APOLLOTYRE': 0, 'JUBLFOOD': 0, 'POWERINDIA': 0, 'MSUMI': 0, 'BANDHANBNK': 0, 'DEEPAKNTR': 0, 'ZFCVINDIA': 0, 'AJANTPHARM': 0, 'KPRMILL': 0, 'SYNGENE': 0, 'EIHOTEL': 0, 'APARINDS': 0, 'NATIONALUM': 0, 'TATACHEM': 0, 'GLENMARK': 0, 'HINDCOPPER': 0, 'GODREJIND': 0, 'NH': 0, 'BLUESTARCO': 0, 'EXIDEIND': 0, 'ENDURANCE': 0, 'JBCHEPHARM': 0, 'PAYTM': 0, 'ANGELONE': 0, 'MOTILALOFS': 0, 'ITI': 0, '360ONE': 0, 'CARBORUNIV': 0, 'AARTIIND': 0, 'SUNTV': 0, 'KIOCL': 0, 'ISEC': 0, 'RADICO': 0, 'SUNDRMFAST': 0, 'CREDITACC': 0, 'COCHINSHIP': 0, 'HATSUN': 0, 'MANYAVAR': 0, 'CYIENT': 0, 'GET&D': 0, 'BRIGADE': 0, 'TIMKEN': 0, 'NBCC': 0, 'JBMA': 0, 'GILLETTE': 0, 'KANSAINER': 0, 'LAURUSLABS': 0, 'GRINDWELL': 0, 'SWANENERGY': 0, 'CHOLAHLDNG': 0, 'IRCON': 0, 'SKFINDIA': 0, 'BSOFT': 0, 'ASTERDM': 0, 'RELAXO': 0, 'SONATSOFTW': 0, 'GSPL': 0, 'RATNAMANI': 0, 'ABFRL': 0, 'APLLTD': 0, 'PFIZER': 0, 'RAMCOCEM': 0, 'PEL': 0, 'ELGIEQUIP': 0, 'LALPATHLAB': 0, 'EMAMILTD': 0, 'SANOFI': 0, 'TRID ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Program Files\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Open'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[35], line 3
#       1 # remove outliers from the data df2 and store it in df3
#       2 df3 = df2.copy()
# ----> 3 df3.drop(df3[(df3['Open'] < lower_bound) | (df3['Open'] > upper_bound)].index, inplace=True)
#       4 df3.drop(df3[(df3['High'] < lower_bound) | (df3['High'] > upper_bound)].index, inplace=True)
#       5 df3.drop(df3[(df3['Low'] < lower_bound) | (df3['Low'] > upper_bound)].index, inplace=True)
#
# File c:\Program Files\Python312\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Program Files\Python312\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Open'

# %%
# Out:
# (8470, 1242)
