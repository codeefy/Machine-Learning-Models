# %%
# Out:
#          Date  RELIANCE  TCS  HDFCBANK  ICICIBANK  BHARTIARTL  SBIN  INFY  \
# 0  1991-01-02       NaN  NaN       NaN        NaN         NaN   NaN   NaN
# 1  1991-01-03       NaN  NaN       NaN        NaN         NaN   NaN   NaN
# 2  1991-01-04       NaN  NaN       NaN        NaN         NaN   NaN   NaN
# 3  1991-01-07       NaN  NaN       NaN        NaN         NaN   NaN   NaN
# 4  1991-01-08       NaN  NaN       NaN        NaN         NaN   NaN   NaN
#
#    LICI  ITC  ...  COOLCAPS  ALLETEC  20MICRONS  VIKASECO  ORIENTBELL  DONEAR  \
# 0   NaN  NaN  ...       NaN      NaN        NaN       NaN         NaN     NaN
# 1   NaN  NaN  ...       NaN      NaN        NaN       NaN         NaN     NaN
# 2   NaN  NaN  ...       NaN      NaN        NaN       NaN         NaN     NaN
# 3   NaN  NaN  ...       NaN      NaN        NaN       NaN         NaN     NaN
# 4   NaN  NaN  ...       NaN      NaN        NaN       NaN         NaN     NaN
#
#    CAREERP  INTLCONV  SHREEPUSHK  PRITIKAUTO
# ...

# %%
# Out:
# ['JIOFIN', 'ADANIENSOL', 'MANKIND', 'JSWINFRA', 'TATATECH', 'L&TFH', 'IREDA', 'MEDANTA', 'LLOYDSME', 'FIVESTAR', 'SIGNATURE', 'JYOTICNC', 'KAYNES', 'KPIL', 'RRKABEL', 'PPLPHARMA', 'NUVAMA', 'CELLO', 'NSLNISP', 'CONCORDBIO', 'HONASA', 'PVRINOX', 'ARE&M', 'BIKAJI', 'JUNIPER', 'INOXINDIA', 'KFINTECH', 'PTCIL', 'DOMS', 'REDTAPE', 'NETWEB', 'SBFC', 'HAPPYFORGE', 'SYRMA', 'ACI', 'AZAD', 'JLHL', 'TMB', 'EMIL', 'RUSTOMJEE', 'NIITMTS', 'TVSSCS', 'INDIASHLTR', 'BLUEJET', 'LTFOODS', 'SENCO', 'SANDUMA', 'UJJIVAN', 'CYIENTDLM', 'ASKAUTOLTD', 'LLOYDSENGG', 'HNDFDS', 'UTKARSHBNK', 'FUSION', 'SULA', 'SAMHI', 'KIRLPNU', 'EPIGRAL', 'GOPAL', 'SINDHUTRAD', 'ENTERO', 'JSFB', 'FEDFINA', 'PARKHOTELS', 'MAXESTATES', 'AARTIPHARM', 'HARSHA', 'YATHARTH', 'ZAGGLE', 'MEDIASSIST', 'INOXGREEN', 'MUTHOOTMF', 'GENSOL', 'DCXINDIA', 'AVALON', 'KALAMANDIR', 'LANDMARK', 'IDEAFORGE', 'SUNCLAY', 'BLSE', 'ESAFSFB', 'FLAIR', 'DREAMFOLKS', 'INNOVACAP', 'HMAAGRO', 'BAJEL', 'SPECTRUM', 'EXICOM', 'UNIPARTS', 'DIVGIITTS', 'YATRA
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18144\897345658.py in ?()
#       1 # create a new df with columns not in null_cols
#       2 df2 = df.drop(columns=null_cols)
#       3
#       4 # fill the remaining null values with the mean of the column not with date column
# ----> 5 df2.fillna(l, inplace=True)
#       6 df2
#
# c:\Program Files\Python312\Lib\site-packages\pandas\core\generic.py in ?(self, value, method, axis, inplace, limit, downcast)
#    7436                     )
#    7437             elif isinstance(value, ABCDataFrame) and self.ndim == 2:
#    7438                 new_data = self.where(self.notna(), value)._mgr
#    7439             else:
# -> 7440                 raise ValueError(f"invalid fill value with a {type(value)}")
#    7441
#    7442         result = self._constructor_from_mgr(new_data, axes=new_data.axes)
# ...

# %%
#  write code for info of the each column in df2
for i in df2.columns:
    print(df2[i].info()) # info of each column in df2
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 8470 entries, 0 to 8469
# Series name: Date
# Non-Null Count  Dtype
# --------------  -----
# 8470 non-null   object
# dtypes: object(1)
# memory usage: 66.3+ KB
# None
# <class 'pandas.core.series.Series'>
# RangeIndex: 8470 entries, 0 to 8469
# Series name: RELIANCE
# Non-Null Count  Dtype
# --------------  -----
# 8470 non-null   float64
# dtypes: float64(1)
# memory usage: 66.3 KB
# None
# <class 'pandas.core.series.Series'>
# RangeIndex: 8470 entries, 0 to 8469
# Series name: TCS
# Non-Null Count  Dtype
# --------------  -----
# 8470 non-null   float64
# dtypes: float64(1)
# memory usage: 66.3 KB
# None
# <class 'pandas.core.series.Series'>
# RangeIndex: 8470 entries, 0 to 8469
# Series name: HDFCBANK
# Non-Null Count  Dtype
# --------------  -----
# 8470 non-null   float64
# dtypes: float64(1)
# memory usage: 66.3 KB
# None
# <class 'pandas.core.series.Series'>
# RangeIndex: 8470 entries, 0 to 8469
# Series name: ICICIBANK
# ...

# %%
# Perform basic statistical analysis on the stock prices and volumes
for i in df2.columns:
    print(df2[i].describe()) # describe of each column in df
# Out:
# count           8470
# unique          8470
# top       1991-01-02
# freq               1
# Name: Date, dtype: object
# count    8470.000000
# mean      605.661551
# std       687.533972
# min        10.975116
# 25%        68.142830
# 50%       443.062775
# 75%       605.661551
# max      3177.250000
# Name: RELIANCE, dtype: float64
# count    8470.000000
# mean     1221.558660
# std       938.477755
# min        35.474998
# 25%       527.012512
# 50%      1221.558660
# 75%      1236.475037
# max      4219.250000
# Name: TCS, dtype: float64
# count    8470.000000
# mean      437.622147
# std       486.047663
# min         2.435000
# 25%        36.157499
# 50%       294.087509
# 75%       535.462479
# max      1768.650024
# Name: HDFCBANK, dtype: float64
# count    8470.000000
# mean      296.793689
# std       213.289896
# min        20.100000
# 25%       171.468182
# 50%       296.793689
# 75%       296.793689
# max      1233.400024
# Name: ICICIBANK, dtype: float64
# ...

# %%
# now we have to perform eda on the data

# 1. check for null values
print(df2.isnull().sum())
# Out:
# Date          0
# RELIANCE      0
# TCS           0
# HDFCBANK      0
# ICICIBANK     0
#              ..
# DONEAR        0
# CAREERP       0
# INTLCONV      0
# SHREEPUSHK    0
# PRITIKAUTO    0
# Length: 1242, dtype: int64
# 0

# %%
# 2. check for duplicate values
print(df2.duplicated().sum())
# Out:
# 0

# %%
# is there any way to check outlier in the data without visualization 
# perform except date column
for i in df2.columns:
    if i != 'Date':
        q1 = df2[i].quantile(0.25)
        q3 = df2[i].quantile(0.75)
        iqr = q3 - q1
        lower_bound = q1 -(1.5 * iqr) 
        upper_bound = q3 +(1.5 * iqr) 
        print(i, df2[(df2[i] < lower_bound) | (df2[i] > upper_bound)].shape[0]) # number of outliers in each column except Date column
# Out:
# RELIANCE 1045
# TCS 949
# HDFCBANK 912
# ICICIBANK 974
# BHARTIARTL 2180
# SBIN 335
# INFY 923
# LICI 528
# ITC 0
# HINDUNILVR 1232
# LT 1776
# BAJFINANCE 1006
# HCLTECH 877
# MARUTI 739
# SUNPHARMA 127
# ADANIENT 812
# KOTAKBANK 1116
# TITAN 955
# ONGC 0
# TATAMOTORS 161
# NTPC 2147
# AXISBANK 154
# DMART 1801
# ADANIGREEN 1492
# ADANIPORTS 2551
# ULTRACEMCO 810
# ASIANPAINT 955
# COALINDIA 3368
# BAJAJFINSV 956
# BAJAJ-AUTO 355
# POWERGRID 2320
# NESTLEIND 1173
# WIPRO 624
# M&M 249
# IOC 529
# HAL 1546
# DLF 962
# ADANIPOWER 541
# JSWSTEEL 858
# TATASTEEL 764
# SIEMENS 791
# IRFC 847
# VBL 1892
# ZOMATO 729
# PIDILITIND 928
# GRASIM 1065
# SBILIFE 1668
# BEL 703
# LTIM 1964
# TRENT 756
# PNB 1284
# INDIGO 2134
# BANKBARODA 163
# HDFCLIFE 1636
# ABB 1872
# BPCL 5
# PFC 1562
# GODREJCP 664
# TATAPOWER 672
# HINDALCO 832
# HINDZINC 2704
# TECHM 2816
# AMBUJACEM 1223
# INDUSINDBK 178
# CIPLA 228
# GAIL 126
# RECLTD 1488
# BRITANNIA 934
# UNIONBANK 2153
# IOB 501
# LODHA 795
# ...

# %%
# store the index of the outliers in a list
l = df2[(df2[i] < lower_bound) | (df2[i] > upper_bound)].index
print(l)
print(len(l)) # number of outliers in the data
# Out:
# Index([7753, 7754, 7755, 7756, 7757, 7758, 7759, 7760, 7761, 7762,
#        ...
#        8460, 8461, 8462, 8463, 8464, 8465, 8466, 8467, 8468, 8469],
#       dtype='int64', length=717)
# 717

# %%
#remove the outliers from the data 
df2.drop(index=l, inplace=True)
print(df2.shape) # shape of the data after removing the outliers
# Out:
# (7753, 1242)

# %%
# chek for the outliers after removing the outliers
for i in df2.columns:
    if i != 'Date':
        q1 = df2[i].quantile(0.25)
        q3 = df2[i].quantile(0.75)
        iqr = q3 - q1
        lower_bound = q1 -(1.5 * iqr) 
        upper_bound = q3 +(1.5 * iqr) 
        print(i, df2[(df2[i] < lower_bound) | (df2[i] > upper_bound)].shape[0]) # number of outliers in each column except Date column
# Out:
# RELIANCE 309
# TCS 218
# HDFCBANK 577
# ICICIBANK 246
# BHARTIARTL 1393
# SBIN 0
# INFY 253
# LICI 0
# ITC 0
# HINDUNILVR 767
# LT 1160
# BAJFINANCE 285
# HCLTECH 218
# MARUTI 309
# SUNPHARMA 25
# ADANIENT 95
# KOTAKBANK 489
# TITAN 237
# ONGC 0
# TATAMOTORS 273
# NTPC 1363
# AXISBANK 321
# DMART 1084
# ADANIGREEN 775
# ADANIPORTS 1054
# ULTRACEMCO 138
# ASIANPAINT 212
# COALINDIA 2651
# BAJAJFINSV 606
# BAJAJ-AUTO 128
# POWERGRID 176
# NESTLEIND 456
# WIPRO 179
# M&M 0
# IOC 650
# HAL 829
# DLF 349
# ADANIPOWER 0
# JSWSTEEL 111
# TATASTEEL 88
# SIEMENS 93
# IRFC 130
# VBL 1175
# ZOMATO 12
# PIDILITIND 174
# GRASIM 298
# SBILIFE 951
# BEL 1
# LTIM 1247
# TRENT 28
# PNB 1664
# INDIGO 1417
# BANKBARODA 70
# HDFCLIFE 919
# ABB 633
# BPCL 1035
# PFC 840
# GODREJCP 151
# TATAPOWER 0
# HINDALCO 121
# HINDZINC 2111
# TECHM 1777
# AMBUJACEM 461
# INDUSINDBK 724
# CIPLA 84
# GAIL 1
# RECLTD 941
# BRITANNIA 802
# UNIONBANK 2372
# IOB 581
# LODHA 78
# EICHERMOT 719
# CANBK 2099
# ...

# %%
# Out:
# <Axes: >
